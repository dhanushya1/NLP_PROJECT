# %%
import json, requests, re, os, traceback
from pathlib import Path
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import os
from time import time, sleep
import json

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()

# %%
driver.get("https://collegedunia.com/university/56859-pes-university-electronic-city-campus-bangalore/reviews")

# %%
reviews = driver.find_elements(By.CLASS_NAME, "jsx-963772526.jsx-2133140133.review-card.pt-4.pb-4.avatar-container")

# %%
len(reviews)
data =[]

# %%
for i in reviews: 
    WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "read.text-white.bg-primary.hover-underline.font-weight-semi.py-2.px-3.text-md")))
    readmore = i.find_elements(By.CLASS_NAME,"read.text-white.bg-primary.hover-underline.font-weight-semi.py-2.px-3.text-md")
    if(len(readmore)>0):
        i.execute_script("arguments[0].click();",readmore[0])
        print("clicked readmore")
        sleep(1)
        WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "jsx-1494674543.review-page-content")))
        review_content = driver.find_elements(By.CSS_SELECTOR, "p")
        data.append(x)
        x= [content.text for content in review_content]
        print(data[len(data)-1])
        driver.get("https://collegedunia.com/university/56859-pes-university-electronic-city-campus-bangalore/reviews")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Sanchana M\OneDrive\Documents\Dhanushya\SEM 6\NLP\PROJECT\NLP_PROJECT\scrap.ipynb Cell 6 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Sanchana%20M/OneDrive/Documents/Dhanushya/SEM%206/NLP/PROJECT/NLP_PROJECT/scrap.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> readmore = i.find_elements(By.CLASS_NAME,"read.text-white.bg-primary.hover-underline.font-weight-semi.py-2.px-3.text-md")
#       <a href='vscode-notebook-cell:/c%3A/Users/Sanchana%20M/OneDrive/Documents/Dhanushya/SEM%206/NLP/PROJECT/NLP_PROJECT/scrap.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> if(len(readmore)>0):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sanchana%20M/OneDrive/Documents/Dhanushya/SEM%206/NLP/PROJECT/NLP_PROJECT/scrap.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     i.execute_script("arguments[0].click();",readmore[0])
# ...

# %%
for i in range(len(data)):
    print(data[i])
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', "I got a mechanical branch on merit via the CET exam. Application forms and fees and dates can be found on college websites. The admission process is very good as it was one the top college's in Bangalore and highly maintained", "I had an interest in machines, motors and the craze of it working so chose this branch. Faculty were highly qualified and relationship with students was good. As I said it's one of the renowned colleges it includes some great PhD holders faculty and other high qualifications too. Exams were conducted semester wise and internal were medium-level diff
# ...
